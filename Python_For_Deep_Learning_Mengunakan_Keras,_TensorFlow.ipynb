# %% [markdown]
# <a href="https://colab.research.google.com/github/Enn17/Studi-Independen_Orbit-Future-Academy/blob/main/Python_For_Deep_Learning_Mengunakan_Keras%2C_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORT LIBRARY YANG DIBUTUHKAN**
#
# > Numpy
#
# > Pandas

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# **MENYIAPKAN DATASET**

# %%
# !wget -O diabetes_latih.csv https://raw.githubusercontent.com/jumadi-cloud/Fundamental-Python/main/Dataset/diabetes_latih.csv

# !wget -O diabetes_uji.csv https://raw.githubusercontent.com/jumadi-cloud/Fundamental-Python/main/Dataset/diabetes_uji.csv

df = pd.read_csv('diabetes_latih.csv')

X_train = df.values
X_train = np.delete(X_train,8, axis=1)

y_train = df['Outcome'].values

df = pd.read_csv('diabetes_uji.csv')

X_test = df.values
X_test = np.delete(X_test,8,axis=1)

y_test = df['Outcome'].values
# Out:
# --2021-09-30 18:07:21--  https://raw.githubusercontent.com/jumadi-cloud/Fundamental-Python/main/Dataset/diabetes_latih.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18518 (18K) [text/plain]
# Saving to: ‘diabetes_latih.csv’
#
# diabetes_latih.csv  100%[===================>]  18.08K  --.-KB/s    in 0s
#
# 2021-09-30 18:07:21 (55.8 MB/s) - ‘diabetes_latih.csv’ saved [18518/18518]
#
# --2021-09-30 18:07:21--  https://raw.githubusercontent.com/jumadi-cloud/Fundamental-Python/main/Dataset/diabetes_uji.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %% [markdown]
# **NORMALISASI DATA SECARA OTOMATIS MENGUNAKAN LIBRARY SKLEARN**

# %%
from sklearn.preprocessing import MinMaxScaler
X_train = MinMaxScaler().fit_transform(X_train)
X_test = MinMaxScaler().fit_transform(X_test)

# %% [markdown]
# **MEMBUAT MODEL ATAU KERANGKA DARI DEEP LEARNING MENGUNAKAN KERAS**

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

model.add(Dense(12, activation='relu', input_shape=(8,)))

model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **MELIHAT MODEL YANG SUDAH KITA BUAT**

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_20 (Dense)             (None, 12)                108
# _________________________________________________________________
# dense_21 (Dense)             (None, 8)                 104
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 9
# ...
# Total params: 293
# Trainable params: 293
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **MELIHAT DATASET**

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# **PROSES TRAINING**

# %%
model.fit(X_train, y_train, epochs=200, verbose=1, batch_size=20)

y_pred = model.predict(X_test)
y_pred = y_pred >= 0.13
# Out:
# Epoch 1/200
# 31/31 [==============================] - 1s 1ms/step - loss: 0.7188 - accuracy: 0.3648
# Epoch 2/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6874 - accuracy: 0.5977
# Epoch 3/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.6694
# Epoch 4/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.6922
# Epoch 5/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6675 - accuracy: 0.6987
# Epoch 6/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6611 - accuracy: 0.6857
# Epoch 7/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6938
# Epoch 8/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6462 - accuracy: 0.6938
# Epoch 9/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.6971
# Epoch 10/200
# ...

# %% [markdown]
# **LIAT ACCURACY MENGUNAKAN LIBRARY ACCURACY_SCORE**

# %%
from sklearn.metrics import accuracy_score

round(accuracy_score(y_test, y_pred),3)
# Out:
# 0.617

# %% [markdown]
# Tentu saja ini hasil yang kurang baik, hanya saja kita coba di **hydrometernya**
#
# ke depan Temen temen bisa coba coba berapa leyer yang cocok, epochs yang cocok dan batch yang cocok
#
# Jika ingin mendalami Deep Learning di sarankan mengunakan dataset mengenali garis wajah, bentuk wajah, organ yang ada disekitar wajah, dan terakhir merepresentasikan wajah secara keseluruhan (tensorflow)
#
# **Pada case ini ingin memberikan pengetahuan basic mengunakan dataset CSV, Load melalui Github dan hydrometernya**
#
# Thank You
